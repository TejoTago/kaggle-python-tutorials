# %% [markdown]
# ## Sumário
#
# O objectivo deste tutorial é apresentar as funcionalidades da biblioteca Pandas para análise de dados.
# O tutorial está organizado em 5 capítulos:
#
# I - Importação de csv e excel
#
# II - Análise exploratória de dados
#
# III - Index, Slice, Select
#
# IV - Limpeza e transformação de dados
#
# V - Visualização de dados
#
# Este notebook debruça-se sobre o **capítulo III** que mostra como aceder a colunas ou linhas específicas, como extrair subconjuntos de dados que obedecem a determinadas condições, etc.
#
# Cada capítulo segue a seguinte estrutura: introdução, tabela sumário, secções e subsecções.

# %% [markdown]
# # [**I. Index, Slice and Select**](#Índice)  <a class="anchor"  id="c1"></a>

# %% [markdown]
# ## Índice <a class="anchor"  id="Índice"></a>
#
# * [Introdução](#IIIi)
# * [Tabela sumário](#IIIt)
# * [1. Seleccionar colunas](#III1)
#     * [1.1 Aceder via nome da coluna](#III11)
#     * [1.2 Aceder via atributo](#III12)
#     * [1.3 Aceder via posição da coluna (index)](#III13)
# * [2. Seleccionar linhas](#III2)
# * [3. Seleccionar com .iloc](#III3)
#     * [3.1 Seleccionar colunas](#III31)
#     * [3.2 Seleccionar linhas](#III32)
#     * [3.3 Seleccionar colunas e linhas](#III33)
#     * [3.4 Seleccionar células](#III34)
# * [4. Seleccionar com .loc](#III4)
#     * [4.1 Seleccionar colunas](#III41)
#     * [4.2 Seleccionar linhas](#III42)
#     * [4.3 Seleccionar colunas e linhas](#III43)
#     * [4.4 Seleccionar células](#III44)
# * [5. iloc vs. .loc](#III5)
# * [6. Filtrar (seleccionar com condições)](#III6)
#     * [6.1 Excluir NA](#III61)
#     * [6.2 Excluir valores duplicados](#III62)
#     * [6.3 Operadores ==, >=...](#III63)
#     * [6.4 &, ~](#III64)
#     * [6.5 Selecionar uma lista de valores para uma coluna | .isin()](#III65)
#     * [6.6 .startswith(), endswith(), contains()](#III66)
#     * [6.7 query](#II67)
# * [7. .at e .iat](#II7)

# %% [markdown]
# # [**Introdução**](#Índice)  <a class="anchor"  id="Ii"></a>
#
# Exemplos do que é possível com estas funcionalidades.

# %% [markdown]
# # [**Tabela sumário**](#Índice) <a class="anchor"  id="IIIt"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# a           | b  |

# %% [markdown]
# # [**1. Seleccionar colunas**](#Índice)  <a class="anchor"  id="III1"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|Exemplo|
# :----|:---------------------------------|:---------------------------------|----|
# Aceder via nome da(s) coluna(s)         | table['col']  |
# Aceder via atributo Python         | table.col, col como atributo |
# Aceder via posição da coluna (index)        | iloc[:,col_index] | table.iloc[:,col_index]
# Aceder via nome da coluna

# %%
#Preparar o ambiente. Selecionar o endereço do arquivo abaixo.
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/P_Data_Extract_From_World_Development_Indicators.xlsx
# /kaggle/input/88c52f5e-f72c-406d-a2e2-31309c9953de_Series - Metadata.csv
# /kaggle/input/88c52f5e-f72c-406d-a2e2-31309c9953de_Data.csv

# %%
file = '/kaggle/input/88c52f5e-f72c-406d-a2e2-31309c9953de_Data.csv'

table1 = pd.read_csv(file)

table1.head()
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## [**1.1 Aceder via nome da coluna**](#Índice)  <a class="anchor"  id="III11"></a>

# %%
table1['Time']
# Out:
# 0                                                   1990
# 1                                                   1990
# 2                                                   1990
# 3                                                   1990
# 4                                                   1990
#                               ...
# 3192                                                 NaN
# 3193                                                 NaN
# 3194                                                 NaN
# 3195    Data from database: World Development Indicators
# 3196                            Last Updated: 10/26/2023
# Name: Time, Length: 3197, dtype: object

# %% [markdown]
# ## [**1.2 Aceder via atributo**](#Índice)  <a class="anchor"  id="III12"></a>
#
# tbc

# %% [markdown]
# ## [**1.3 Aceder via posição da coluna (index)**](#Índice)  <a class="anchor"  id="III13"></a>
#
# iloc e loc (linhas, colunas). Primeiro a posição das linhas e depois a posição das colunas. Por exemplo, table.iloc[1,2] dá-nos a célula que resulta da intersecção da linha com index 1 e da coluna com index 2, ou seja, da segunda linha e da terceira coluna dado que o index começa no zero.

# %%
"""
: - todas as linhas;
1 - coluna com a posição 1, ou seja, a segunda coluna 'Country Name'
"""

table1.iloc[:,1]
# Out:
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3       American Samoa
# 4              Andorra
#              ...
# 3192               NaN
# 3193               NaN
# 3194               NaN
# 3195               NaN
# 3196               NaN
# Name: Country Name, Length: 3197, dtype: object

# %% [markdown]
# # [**2. Seleccionar linhas**](#Índice) <a class="anchor"  id="III2"></a>
#
# O mesmo processo usado na selecção de colunas.

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe
# :----|:---------------------------------|:--------------------------------
# Obter um intervalo de linhas       | table[row_i : row_j]| table[table[row_i, row_j, se o intervalo pretendido for [i,j-1]
# Obter um intervalo de linhas | .iloc|  table.iloc[[ i : j ], :], linhas i até j-1
# Obter um intervalo de linhas | .loc|  table.loc[[ i : j ], :], linhas i até j

# %%
table1[1:5]
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# # [**3. Seleccionar com .iloc**](#Índice) <a class="anchor"  id="III3"></a>
#
# O .iloc permite seleccionar um subconjunto de dados da tabela inicial.
# A sintaxe é tabela.iloc[linhas, colunas].
#
# A selecção é feita com base na posicão no index.
#
# Nota que o index começa na posição 0, tanto para linhas como para colunas.
#
# Primeira coluna: Index 0; segunda linha: Index 1.

# %% [markdown]
# ## [**3.1 Seleccionar colunas**](#Índice)  <a class="anchor"  id="III31"></a>

# %% [markdown]
# table.iloc[linhas, colunas]  |Linhas                    |Colunas                      |Intervalo
# :----------------------------|:-------------------------|:----------------------------|:-------
# [:, 1]                       | Todas                    | 1                           |
# [:, :3]                      | Todas                    | 0, 1 e 2                    | colunas: [0,3**[**
# [:, [2,3] ]                    | Todas                    | 2 e 3                       |
# [:, [3,2] ]                   | Todas                    | 3 e 2                       |
# [:, [1,3,5] ]                  | Todas                    | 1, 3 e 5                    |
# [:, -1]                      | Todas                    | Última                      |
# [:, [-2,-1] ]                | Todas                    | Penúltima e última          |
# [:, [-1,-2]  ]                | Todas                    | Última e penúltima
# [:,::-1] | Todas | Todas as colunas mas por ordem inversa. A última passa a primeira...

# %%
#Todas as linhas, segunda coluna, ie, coluna com posição 1 no index

table1.iloc[:,1].head()
# Out:
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3    American Samoa
# 4           Andorra
# Name: Country Name, dtype: object

# %%
"""
Todas as linhas, todas as colunas à esquerda da coluna na posição 3, 
excluindo esta. Ou seja, colunas 0, 1 e 2.
"""
table1.iloc[:,:3].head()
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN

# %%
#Todas as linhas, duas colunas: coluna index 2 e coluna index 3.
table1.iloc[:,[2,3]]
# Out:
#       Firms with female top manager (% of firms)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)
# 0                                        16.866045
# 1                                        40.805673
# 2                                        12.238081
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
# [3197 rows x 2 columns]

# %%
#Todas as linhas, quarta e terceira coluna, por esta ordem.

table1.iloc[:,[3,2]]
# Out:
#       Labor force, female (% of total labor force)  \
# 0                                        16.866045
# 1                                        40.805673
# 2                                        12.238081
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Firms with female top manager (% of firms)
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
# [3197 rows x 2 columns]

# %%
#Todas as linhas, última coluna
table1.iloc[:,-1]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3192   NaN
# 3193   NaN
# 3194   NaN
# 3195   NaN
# 3196   NaN
# Name: Women who were first married by age 15 (% of women ages 20-24), Length: 3197, dtype: float64

# %%
#Todas as linhas, todas as colunas com a ordem invertida.

table1.iloc[:,::-1].head()
# Out:
#    Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Firms with female top manager (% of firms)    Country Name  Time
# 0                                         NaN     Afghanistan  1990
# 1                                         NaN         Albania  1990
# 2                                         NaN         Algeria  1990
# 3                                         NaN  American Samoa  1990
# 4                                         NaN         Andorra  1990

# %% [markdown]
# ## [**3.2 Seleccionar linhas**](#Índice)  <a class="anchor"  id="III32"></a>

# %% [markdown]
# table.iloc[linhas, colunas]  |Linhas                    |Colunas                      |Intervalo
# :----------------------------|:-------------------------|:----------------------------|:-------
# [5, :]                       | 5                        | Todas                       |
# [:5, :]                      | 0,1,2,3,4                | Todas                       |linhas: [0,5**[**
# [ [4,5], :]                   | 4 e 5                    | Todas                       |
# [-1, :]                      | Última                   | Todas                       |
# [ [1,-1], :]                  | Segunda(Index 1) e última             | Todas                       |
# [ [0,-1, 3], :]               | Primeira (Index 0), última e 3        | Todas                       |

# %%
#Linha 5, todas as colunas

table1.iloc[5, :]
# Out:
# Time                                                                                                                                                1990
# Country Name                                                                                                                                      Angola
# Firms with female top manager (% of firms)                                                                                                           NaN
# Labor force, female (% of total labor force)                                                                                                   49.981317
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                                 NaN
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                                   NaN
# Fertility rate, total (births per woman)                                                                                                           7.272
# Literacy rate, adult female (% of females ages 15 and above)                                                                                         NaN
# Literacy rate, adult total (% of people ages 15 and above)                                                                                           NaN
# Literacy rate, adult male (% of males ages 15 and above)                                                                                             NaN
# Government expenditure on education, total (% of GDP)                                                                                                NaN
# Unmet need for contraception (% of married women ages 15-49)                                                                                         NaN
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)          NaN
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                               NaN
# Women who were first married by age 15 (% of women ages 20-24)                                                                                       NaN
# Name: 5, dtype: object

# %%
#Linhas 0 até 4, todas as colunas

table1.iloc[:5, :]
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Linhas 4 e 5, todas as colunas

table1.iloc[ [4,5], :]
# Out:
#    Time Country Name  Firms with female top manager (% of firms)  \
# 4  1990      Andorra                                         NaN
# 5  1990       Angola                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 4                                           NaN
# 5                                     49.981317
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 4                                                NaN
# 5                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 4                                                NaN
# 5                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 4                                       NaN
# 5                                     7.272
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 4                                                NaN
# 5                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 4                                                NaN
# 5                                                NaN

# %%
#Primeira linha (index 0), última linha e terceira linha (index 4)

table1.iloc[ [0, -1, 4], :]
# Out:
#                           Time Country Name  \
# 0                         1990  Afghanistan
# 3196  Last Updated: 10/26/2023          NaN
# 4                         1990      Andorra
#
#       Firms with female top manager (% of firms)  \
# 0                                            NaN
# 3196                                         NaN
# 4                                            NaN
#
#       Labor force, female (% of total labor force)  \
# 0                                        16.866045
# 3196                                           NaN
# 4                                              NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Fertility rate, total (births per woman)  \
# 0                                        7.565
# 3196                                       NaN
# 4                                          NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                   NaN
# 3196                                                NaN
# 4                                                   NaN

# %% [markdown]
# ## [**3.3 Seleccionar colunas e linhas**](#Índice)  <a class="anchor"  id="III33"></a>

# %% [markdown]
# table.iloc[linhas, colunas]  |Linhas                    |Colunas                      |Intervalo
# :----------------------------|:-------------------------|:----------------------------|:-------
# [:3, 1]                      | 0,1 e 2                  | 1                           |
# [:3,:3]                      | 0,1 e 2                  | 0, 1 e 2                    | linhas e colunas: [0,3**[**
# [:5, [2,3]                   | 0-4                      | 2 e 3                       |
# [[0,1], [3,2]]               | 0 e 1                    | 3 e 2                       |
# [[0,-1], [1,3,5]             | Primeira (Index 0) e última                  | 1, 3 e 5                    |

# %%
#Primeiras 3 linhas (0,1 e 2), coluna com a primeira posição no index (segunda coluna).

table1.iloc[:3, 1]
# Out:
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# Name: Country Name, dtype: object

# %%
#3 primeiras linhas, 3 primeiras colunas.

table1.iloc[:3,:3]
# Out:
#    Time Country Name  Firms with female top manager (% of firms)
# 0  1990  Afghanistan                                         NaN
# 1  1990      Albania                                         NaN
# 2  1990      Algeria                                         NaN

# %%
#Linha na posição 5, colunas na posições 2 e 3.
table1.iloc[5, [2,3] ]
# Out:
# Firms with female top manager (% of firms)            NaN
# Labor force, female (% of total labor force)    49.981317
# Name: 5, dtype: object

# %%
#Primeiras duas linhas, colunas 3 e 2, por esta ordem.

table1.iloc[ [0,1], [3,2] ]
# Out:
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
#
#    Firms with female top manager (% of firms)
# 0                                         NaN
# 1                                         NaN

# %%
#Primeira e última linha, colunas 1, 3 e 5

table1.iloc[ [0,-1], [1, 3, 5] ]
# Out:
#      Country Name  Labor force, female (% of total labor force)  \
# 0     Afghanistan                                     16.866045
# 3196          NaN                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)
# 0                                                   NaN
# 3196                                                NaN

# %% [markdown]
# ## [**3.4 Seleccionar células**](#Índice)  <a class="anchor"  id="III34"></a>

# %% [markdown]
# table.iloc[linhas, colunas]  |Célula |
# :----------------------------|:--------|
# [0,0]                        | (0,0) - primeira linha e primeira coluna |
# [0,1]                        | (1,0) - segunda linha e primeira coluna  |
# [1,2]                        | (1,2) - segunda linha e terceira coluna  |
# [0,-1]                       | (0,-1) - primeira linha e última coluna  |

# %%
table1.iloc[0,0]
# Out:
# '1990'

# %%
table1.iloc[0,1]
# Out:
# 'Afghanistan'

# %%
table1.iloc[1,2]
# Out:
# nan

# %%
table1.iloc[0,-1]
# Out:
# nan

# %% [markdown]
# # [**4. Seleccionar com .loc**](#Índice) <a class="anchor"  id="III4"></a>

# %% [markdown]
# ## [**4.1 Seleccionar colunas**](#Índice)  <a class="anchor"  id="III41"></a>

# %% [markdown]
# table.loc[linhas, colunas]                  |Linhas      |Colunas |Intervalo
# :-------------------------------------------|:-----------|:-------|:----
# [:, 'A']                              | Todas      | A
# [:, :'A']                             | Todas      | A e todas as colunas à esquerda | [Column(Index 0), Column A]
# [:, ['A', 'F']                        | Todas      | A e F
# [:,:]                                       | Todas      | Todas  | = table

# %% [markdown]
# ## [**4.2 Seleccionar linhas**](#Índice)  <a class="anchor"  id="III42"></a>
#
# Por defeito, é criado é um index que numera as linhas,começando no zero.
#
# Se for alterada a composição do index ou se for seleccionada uma das colunas com index,em vez de usarmos números usamos o nome que cada linha tem no index. Por exemplo, se a coluna 'Country Name' for seleccionada como index cada país ocupará uma posição no index. Para seleccionar Brasil: table1.lolc['Brasil',:]

# %% [markdown]
# table.loc[linhas, colunas]  |Linhas                     |Colunas                      |Intervalo
# :----------------------------|:-------------------------|:----------------------------|:-------
# [5, :]                       | 5                        | Todas                       |           |
# [:5, :]                      | 0,1,2,3,4                | A                           |linhas: [0,5**]**
# [ [4,5], :]                   | 4 e 5                    | Todas                       |
# [ [0, 1, 3], :]                      |0, 1 e 3                   | Todas
# [ -1, :]               | -1 não existe como nome no index. Não pode ser seleccionado com .loc      |                  |

# %%
#Linha 5, todas as colunas.

table1.loc[5,:]
# Out:
# Time                                                                                                                                                1990
# Country Name                                                                                                                                      Angola
# Firms with female top manager (% of firms)                                                                                                           NaN
# Labor force, female (% of total labor force)                                                                                                   49.981317
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                                 NaN
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                                   NaN
# Fertility rate, total (births per woman)                                                                                                           7.272
# Literacy rate, adult female (% of females ages 15 and above)                                                                                         NaN
# Literacy rate, adult total (% of people ages 15 and above)                                                                                           NaN
# Literacy rate, adult male (% of males ages 15 and above)                                                                                             NaN
# Government expenditure on education, total (% of GDP)                                                                                                NaN
# Unmet need for contraception (% of married women ages 15-49)                                                                                         NaN
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)          NaN
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                               NaN
# Women who were first married by age 15 (% of women ages 20-24)                                                                                       NaN
# Name: 5, dtype: object

# %%
#Primeiras 6 linhas: linhas 0 à linha 5, inclusive; todas as colunas.

table1.loc[:5, :]
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
# 5  1990          Angola                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
# 5                                     49.981317
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
# 5                                     7.272
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
#Linhas 4 e 5, todas as colunas.

table1.loc[ [4, 5], :]
# Out:
#    Time Country Name  Firms with female top manager (% of firms)  \
# 4  1990      Andorra                                         NaN
# 5  1990       Angola                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 4                                           NaN
# 5                                     49.981317
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 4                                                NaN
# 5                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 4                                                NaN
# 5                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 4                                       NaN
# 5                                     7.272
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 4                                                NaN
# 5                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 4                                                NaN
# 5                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 4                                                NaN
# 5                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 4                                                NaN
# 5                                                NaN

# %%
table1.loc[ [0,1, 3], :]
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 3  1990  American Samoa                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 3                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 3                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN

# %% [markdown]
# ## [**4.3 Seleccionar colunas e linhas**](#Índice)  <a class="anchor"  id="III41"></a>

# %% [markdown]
# table.loc[linhas, colunas]  |Linhas                    |Colunas                      |Intervalo
# :-----------------------------|:-------------------------|:----------------------------|:-------
# [:3, 'A']                     | 0,1,2 e 3                | A                          |[0,3**]**
# [:3,['A','F']]                | 0,1,2 e 3                | A e F                      | linhas [0,3**]**
# [[0,1],['A','F']]             | 0 e 1                    | A e F                      |
# [[0,1],'A':'F']               | 0 e 1                    | A até F                    | linhas [0,1] colunas [A,F]

# %%
#Linhas 0 até 3, inclusive; coluna 'Country Name'

table1.loc[:3, 'Country Name']
# Out:
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3    American Samoa
# Name: Country Name, dtype: object

# %%
table1.loc[:3, ['Time', 'Country Name']]
# Out:
#    Time    Country Name
# 0  1990     Afghanistan
# 1  1990         Albania
# 2  1990         Algeria
# 3  1990  American Samoa

# %%
#Linhas 1 e 2, colunas 1 e 2


table1.loc[ [1,2], ['Country Name','Firms with female top manager (% of firms)']]
# Out:
#   Country Name  Firms with female top manager (% of firms)
# 1      Albania                                         NaN
# 2      Algeria                                         NaN

# %%
#Linhas 0 e 1, colunas entre coluna 'Time' e 'Firms...'

table1.loc[ [0,1], 'Time' : 'Firms with female top manager (% of firms)']
# Out:
#    Time Country Name  Firms with female top manager (% of firms)
# 0  1990  Afghanistan                                         NaN
# 1  1990      Albania                                         NaN

# %% [markdown]
# ## [**4.4 Seleccionar células**](#Índice)  <a class="anchor"  id="III44"></a>

# %% [markdown]
# table.loc[linhas, colunas]  |Célula
# :----------------------------|:--------
# [0,'A']                      | (0,A) - primeira linha e coluna A
# [1,'A']                      | (1,A) - segunda linha e coluna A
# ['a','A']                    | (a,A) - linha a e coluna A

# %%
table1.loc[0,'Firms with female top manager (% of firms)']
# Out:
# nan

# %%
#table1.loc[['Armenia'], :]

"""
Possível apenas se a coluna 'Country Name' fosse o index da tabela e
'Armenia' ocupasse uma posição nesse index.
"""
# Out:
# "\nPossível apenas se a coluna 'Country Name' fosse o index da tabela e\n'Armenia' ocupasse uma posição nesse index.\n"

# %% [markdown]
# # [**5. iloc vs. .loc**](#Índice) <a class="anchor"  id="III5"></a>

# %% [markdown]
# .iloc localiza pela posição no index e .loc pelo nome.
#
# Nota: .iloc funciona com intervalo aberto à direita e .loc com intervalo fechado à direita.
#
# Para seleccionar linhas até 3, inclusive:
#
#     table.iloc[:4,:]   = table.loc[:3,:]

# %% [markdown]
# # [**6. Filtrar (seleccionar com condições)**](#Índice)  <a class="anchor"  id="III6"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# Excluir linhas com valores NA          |.notna() |table[table[ 'column' ].notna()
# Excluir linhas com valores NA          |.dropna()|table[ 'column' ].dropna()
# Excluir valores duplicados             |.drop_duplicates()|table[table[ 'column' ].drop_duplicates()
# Seleccionar valores da coluna iguais a k | == | table[table[ 'column' ] == 'k'
# Seleccionar todos os valores excepto t | != | table[table[ 'column' ] != 'k'
# Seleccionar valores da coluna superiores a k | > | table[ table[ 'column' ] > 'k'
# E | & | table[ ( table['columnA' ] == 'k' ) & ( table[ 'columnA' ] >= 'm' ) ]
# Ou | \| |table[ ( table['columnA' ] == 'j' ) \| ( table[ 'columnB' ] >= 'n' ) ]
# Negação | ~ |table[ table[ 'column' ].isin( [...] ) )
# Filtrar valores constantes de uma lista | isin()| table[ table[ 'column' ].isin( [...] ) )
# Filtrar valores que começam com X | str.startswith() | table1[ table1[ 'Column' ].str.startswith( 'X',na=False )]
# Filtrar valores que terminam com X | str.endswith() | table1[ table1[ 'Column' ].str.endswith( 'X',na=False ) ]
# Filtrar valores que contêm  X | str.contains() | table1[ table1[ 'Column' ].str.contains( 'X',na=False )]

# %% [markdown]
# ## [**6.1 Excluir NA**](#Índice)  <a class="anchor"  id="III61"></a>

# %%
"""
Excluir dos resultados todas as linhas NA na coluna 'Country Name'.

"""

table1[table1['Country Name'].notna()]
# Out:
#       Time                                Country Name  \
# 0     1990                                 Afghanistan
# 1     1990                                     Albania
# 2     1990                                     Algeria
# 3     1990                              American Samoa
# 4     1990                                     Andorra
# ...    ...                                         ...
# 3187  2022                          Sub-Saharan Africa
# 3188  2022  Sub-Saharan Africa (excluding high income)
# 3189  2022   Sub-Saharan Africa (IDA & IBRD countries)
# 3190  2022                         Upper middle income
# 3191  2022                                       World
#
#       Firms with female top manager (% of firms)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3187                                         NaN
# 3188                                         NaN
# 3189                                         NaN
# 3190                                         NaN
# 3191                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 0                                        16.866045
# 1                                        40.805673
# 2                                        12.238081
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3187                                     46.252039
# 3188                                     46.252039
# 3189                                     46.252039
# 3190                                     43.394737
# 3191                                     39.487264
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 0                                        7.565
# 1                                        2.900
# 2                                        4.556
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 3187                                       NaN
# 3188                                       NaN
# 3189                                       NaN
# 3190                                       NaN
# 3191                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          61.437691
# 3188                                          61.433842
# 3189                                          61.437691
# 3190                                          94.710197
# 3191                                          83.783836
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          67.715012
# 3188                                          67.711639
# 3189                                          67.715012
# 3190                                          95.955971
# 3191                                          87.011749
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          74.164963
# 3188                                          74.162201
# 3189                                          74.164963
# 3190                                          97.205338
# 3191                                          90.310654
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                           3.224586
# 3188                                           3.224586
# 3189                                           3.224586
# 3190                                                NaN
# 3191                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
# [3192 rows x 15 columns]

# %%
table1['Country Name'].dropna()
# Out:
# 0                                      Afghanistan
# 1                                          Albania
# 2                                          Algeria
# 3                                   American Samoa
# 4                                          Andorra
#                            ...
# 3187                            Sub-Saharan Africa
# 3188    Sub-Saharan Africa (excluding high income)
# 3189     Sub-Saharan Africa (IDA & IBRD countries)
# 3190                           Upper middle income
# 3191                                         World
# Name: Country Name, Length: 3192, dtype: object

# %% [markdown]
# ## [**6.2 Excluir valores duplicados**](#Índice)  <a class="anchor"  id="III61"></a>

# %%
table1[table1['Country Name'].notna()].drop_duplicates()
# Out:
#       Time                                Country Name  \
# 0     1990                                 Afghanistan
# 1     1990                                     Albania
# 2     1990                                     Algeria
# 3     1990                              American Samoa
# 4     1990                                     Andorra
# ...    ...                                         ...
# 3187  2022                          Sub-Saharan Africa
# 3188  2022  Sub-Saharan Africa (excluding high income)
# 3189  2022   Sub-Saharan Africa (IDA & IBRD countries)
# 3190  2022                         Upper middle income
# 3191  2022                                       World
#
#       Firms with female top manager (% of firms)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3187                                         NaN
# 3188                                         NaN
# 3189                                         NaN
# 3190                                         NaN
# 3191                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 0                                        16.866045
# 1                                        40.805673
# 2                                        12.238081
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3187                                     46.252039
# 3188                                     46.252039
# 3189                                     46.252039
# 3190                                     43.394737
# 3191                                     39.487264
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 0                                        7.565
# 1                                        2.900
# 2                                        4.556
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 3187                                       NaN
# 3188                                       NaN
# 3189                                       NaN
# 3190                                       NaN
# 3191                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          61.437691
# 3188                                          61.433842
# 3189                                          61.437691
# 3190                                          94.710197
# 3191                                          83.783836
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          67.715012
# 3188                                          67.711639
# 3189                                          67.715012
# 3190                                          95.955971
# 3191                                          87.011749
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                          74.164963
# 3188                                          74.162201
# 3189                                          74.164963
# 3190                                          97.205338
# 3191                                          90.310654
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                           3.224586
# 3188                                           3.224586
# 3189                                           3.224586
# 3190                                                NaN
# 3191                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
#
# [3192 rows x 15 columns]

# %%
table1[table1['Women who believe a husband is justified in beating his wife when she goes out without telling him (%)'].notna()]
# Out:
#       Time Country Name  Firms with female top manager (% of firms)  \
# 274   2000      Armenia                                         NaN
# 330   2000     Ethiopia                                         NaN
# 350   2000        Haiti                                         NaN
# 385   2000       Malawi                                         NaN
# 428   2000       Rwanda                                         NaN
# ...    ...          ...                                         ...
# 2506  2020      Liberia                                         NaN
# 2556  2020       Rwanda                                         NaN
# 2749  2021        India                                         NaN
# 2778  2021   Madagascar                                         NaN
# 2785  2021   Mauritania                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 274                                      48.794123
# 330                                      44.781638
# 350                                      45.932066
# 385                                      50.406097
# 428                                      45.915351
# ...                                            ...
# 2506                                     47.870094
# 2556                                     46.414761
# 2749                                     23.019117
# 2778                                     48.842986
# 2785                                     33.588938
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                                 NaN
# ...                                                 ...
# 2506                                                NaN
# 2556                                                NaN
# 2749                                                NaN
# 2778                                                NaN
# 2785                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                                 NaN
# ...                                                 ...
# 2506                                                NaN
# 2556                                                NaN
# 2749                                                NaN
# 2778                                                NaN
# 2785                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 274                                      1.603
# 330                                      6.560
# 350                                      4.390
# 385                                      6.036
# 428                                      5.924
# ...                                        ...
# 2506                                     4.174
# 2556                                     3.873
# 2749                                     2.031
# 2778                                     3.851
# 2785                                     4.398
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                           59.750340
# ...                                                 ...
# 2506                                                NaN
# 2556                                                NaN
# 2749                                                NaN
# 2778                                                NaN
# 2785                                          62.169998
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                           64.888603
# ...                                                 ...
# 2506                                                NaN
# 2556                                                NaN
# 2749                                                NaN
# 2778                                                NaN
# 2785                                          66.959999
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                           71.419380
# ...                                                 ...
# 2506                                                NaN
# 2556                                                NaN
# 2749                                                NaN
# 2778                                                NaN
# 2785                                          71.779999
#
#       Government expenditure on education, total (% of GDP)  \
# 274                                            2.772730
# 330                                            3.983110
# 350                                                 NaN
# 385                                            3.606130
# 428                                            3.434310
# ...                                                 ...
# 2506                                           2.139915
# 2556                                           3.333943
# 2749                                           4.635141
# 2778                                           3.198076
# 2785                                           1.745530
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 274                                                18.1
# 330                                                36.6
# 350                                                39.6
# 385                                                29.9
# 428                                                36.4
# ...                                                 ...
# 2506                                               33.4
# 2556                                               13.6
# 2749                                                9.4
# 2778                                               14.6
# 2785                                               31.1
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 274                                                 NaN
# 330                                                 NaN
# 350                                                 NaN
# 385                                                 NaN
# 428                                                 NaN
# ...                                                 ...
# 2506                                               62.2
# 2556                                               63.0
# 2749                                                NaN
# 2778                                                NaN
# 2785                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 274                                                19.9
# 330                                                56.2
# 350                                                28.8
# 385                                                16.6
# 428                                                36.6
# ...                                                 ...
# 2506                                               23.1
# 2556                                               37.6
# 2749                                               20.9
# 2778                                               22.1
# 2785                                               16.7
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 274                                                 0.8
# 330                                                19.1
# 350                                                 5.3
# 385                                                10.2
# 428                                                 2.1
# ...                                                 ...
# 2506                                                5.8
# 2556                                                0.3
# 2749                                                4.0
# 2778                                               12.7
# 2785                                               15.5
#
# [75 rows x 15 columns]

# %% [markdown]
# ## [**6.3 Operadores ==, >=...**](#Índice)  <a class="anchor"  id="III63"></a>

# %%
table1[table1['Country Name'] == 'Brazil']
# Out:
#       Time Country Name  Firms with female top manager (% of firms)  \
# 26    1990       Brazil                                         NaN
# 292   2000       Brazil                                         NaN
# 558   2013       Brazil                                         NaN
# 824   2014       Brazil                                         NaN
# 1090  2015       Brazil                                         NaN
# 1356  2016       Brazil                                         NaN
# 1622  2017       Brazil                                         NaN
# 1888  2018       Brazil                                         NaN
# 2154  2019       Brazil                                         NaN
# 2420  2020       Brazil                                         NaN
# 2686  2021       Brazil                                         NaN
# 2952  2022       Brazil                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 26                                       34.913911
# 292                                      40.193869
# 558                                      42.123945
# 824                                      42.217141
# 1090                                     42.553791
# 1356                                     42.705732
# 1622                                     43.230434
# 1888                                     43.432423
# 2154                                     43.736217
# 2420                                     42.605281
# 2686                                     43.117615
# 2952                                     43.579161
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                           11.60814
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                            5.13276
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 26                                       2.905
# 292                                      2.255
# 558                                      1.748
# 824                                      1.767
# 1090                                     1.777
# 1356                                     1.709
# 1622                                     1.736
# 1888                                     1.749
# 2154                                     1.703
# 2420                                     1.649
# 2686                                     1.641
# 2952                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 26                                                  NaN
# 292                                           86.500053
# 558                                           91.764961
# 824                                           92.060516
# 1090                                          92.343788
# 1356                                          93.021202
# 1622                                          93.243713
# 1888                                          93.425072
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.919998
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 26                                                  NaN
# 292                                           86.367882
# 558                                           91.484238
# 824                                           91.729431
# 1090                                          92.047897
# 1356                                          92.808441
# 1622                                          93.075821
# 1888                                          93.227501
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.690002
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 26                                                  NaN
# 292                                           86.227982
# 558                                           91.177963
# 824                                           91.366768
# 1090                                          91.725159
# 1356                                          92.575157
# 1622                                          92.891533
# 1888                                          93.009041
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.449997
#
#       Government expenditure on education, total (% of GDP)  \
# 26                                                  NaN
# 292                                             3.94893
# 558                                             5.83885
# 824                                             5.94848
# 1090                                            6.24106
# 1356                                            6.31404
# 1622                                            6.32048
# 1888                                            6.08851
# 2154                                            5.96347
# 2420                                            5.77150
# 2686                                                NaN
# 2952                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                                NaN
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                                NaN
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                                NaN
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 26                                                  NaN
# 292                                                 NaN
# 558                                                 NaN
# 824                                                 NaN
# 1090                                                NaN
# 1356                                                NaN
# 1622                                                NaN
# 1888                                                NaN
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN

# %%
# Todos os valores da coluna 'Time' excepto 1990

table1[table1['Time'] != '1990']
# Out:
#                                                   Time    Country Name  \
# 266                                               2000     Afghanistan
# 267                                               2000         Albania
# 268                                               2000         Algeria
# 269                                               2000  American Samoa
# 270                                               2000         Andorra
# ...                                                ...             ...
# 3192                                               NaN             NaN
# 3193                                               NaN             NaN
# 3194                                               NaN             NaN
# 3195  Data from database: World Development Indicators             NaN
# 3196                          Last Updated: 10/26/2023             NaN
#
#       Firms with female top manager (% of firms)  \
# 266                                          NaN
# 267                                          NaN
# 268                                          NaN
# 269                                          NaN
# 270                                          NaN
# ...                                          ...
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 266                                      16.542629
# 267                                      42.026200
# 268                                      13.828949
# 269                                            NaN
# 270                                            NaN
# ...                                            ...
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 266                                      7.534
# 267                                      2.231
# 268                                      2.566
# 269                                        NaN
# 270                                        NaN
# ...                                        ...
# 3192                                       NaN
# 3193                                       NaN
# 3194                                       NaN
# 3195                                       NaN
# 3196                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 266                                                 NaN
# 267                                             3.43017
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
# [2931 rows x 15 columns]

# %% [markdown]
# ## [**6.4 Operadores lógicos &, |, ~**](#Índice)  <a class="anchor"  id="III64"></a>

# %%
# & - And; Necessita parêntesis.


table1.loc[(table1['Time']>='2019') & (table1['Country Name'] == 'Brazil'),['Country Name', 'Time','Government expenditure on education, total (% of GDP)']]
# Out:
#      Country Name  Time  Government expenditure on education, total (% of GDP)
# 2154       Brazil  2019                                            5.96347
# 2420       Brazil  2020                                            5.77150
# 2686       Brazil  2021                                                NaN
# 2952       Brazil  2022                                                NaN

# %%
table1.loc[(table1['Time']>'2015') & (table1['Country Name'] == 'India'),['Time','Country Name','Women who believe a husband is justified in beating his wife when she goes out without telling him (%)']].dropna()
# Out:
#       Time Country Name  \
# 1419  2016        India
# 2749  2021        India
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 1419                                               26.1
# 2749                                               20.9

# %%
table1[(table1['Country Name'].notna()) & (table1['Time'] == '2020')].drop_duplicates()
# Out:
#       Time                                Country Name  \
# 2394  2020                                 Afghanistan
# 2395  2020                                     Albania
# 2396  2020                                     Algeria
# 2397  2020                              American Samoa
# 2398  2020                                     Andorra
# ...    ...                                         ...
# 2655  2020                          Sub-Saharan Africa
# 2656  2020  Sub-Saharan Africa (excluding high income)
# 2657  2020   Sub-Saharan Africa (IDA & IBRD countries)
# 2658  2020                         Upper middle income
# 2659  2020                                       World
#
#       Firms with female top manager (% of firms)  \
# 2394                                         NaN
# 2395                                         NaN
# 2396                                         NaN
# 2397                                         NaN
# 2398                                         NaN
# ...                                          ...
# 2655                                         NaN
# 2656                                         NaN
# 2657                                         NaN
# 2658                                         NaN
# 2659                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 2394                                     19.793486
# 2395                                     43.822864
# 2396                                     19.229614
# 2397                                           NaN
# 2398                                           NaN
# ...                                            ...
# 2655                                     46.053642
# 2656                                     46.053642
# 2657                                     46.053642
# 2658                                     43.367952
# 2659                                     39.350260
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 2394                                  4.750000
# 2395                                  1.400000
# 2396                                  2.942000
# 2397                                       NaN
# 2398                                       NaN
# ...                                        ...
# 2655                                  4.666824
# 2656                                  4.667023
# 2657                                  4.666824
# 2658                                  1.631490
# 2659                                  2.299626
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                          61.142250
# 2656                                          61.138210
# 2657                                          61.142250
# 2658                                          94.703873
# 2659                                          83.325203
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                          67.547630
# 2656                                          67.544113
# 2657                                          67.547630
# 2658                                          95.956917
# 2659                                          86.711510
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                          74.174362
# 2656                                          74.171494
# 2657                                          74.174362
# 2658                                          97.214653
# 2659                                          90.114662
#
#       Government expenditure on education, total (% of GDP)  \
# 2394                                                NaN
# 2395                                           3.342300
# 2396                                           7.042397
# 2397                                                NaN
# 2398                                           2.856163
# ...                                                 ...
# 2655                                           3.819201
# 2656                                           3.819201
# 2657                                           3.819201
# 2658                                           4.342245
# 2659                                           4.444077
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 2394                                                NaN
# 2395                                                NaN
# 2396                                                NaN
# 2397                                                NaN
# 2398                                                NaN
# ...                                                 ...
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
#
# [266 rows x 15 columns]

# %%
#| - Or; necessita parêntesis. 
#table.loc[ (table[col1] condição) & [table[col2] condição), [col1, col2, ...]]

table1.loc[(table1['Time']>'2015') & ((table1['Country Name'] == 'India') | (table1['Country Name'] == 'Madagascar')) ,['Time','Country Name','Women who believe a husband is justified in beating his wife when she goes out without telling him (%)']].dropna()
# Out:
#       Time Country Name  \
# 1419  2016        India
# 2749  2021        India
# 2778  2021   Madagascar
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)
# 1419                                               26.1
# 2749                                               20.9
# 2778                                               22.1

# %%
#Quite different!! ;)

#table1[table1['Time'] == '2020'].dropna().drop_duplicates()

# %%
table1[(table1['Country Name'] == 'Brazil')  & (table1['Time'] >= '2019')].drop_duplicates()
# Out:
#       Time Country Name  Firms with female top manager (% of firms)  \
# 2154  2019       Brazil                                         NaN
# 2420  2020       Brazil                                         NaN
# 2686  2021       Brazil                                         NaN
# 2952  2022       Brazil                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 2154                                     43.736217
# 2420                                     42.605281
# 2686                                     43.117615
# 2952                                     43.579161
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 2154                                     1.703
# 2420                                     1.649
# 2686                                     1.641
# 2952                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.919998
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.690002
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                          94.449997
#
#       Government expenditure on education, total (% of GDP)  \
# 2154                                            5.96347
# 2420                                            5.77150
# 2686                                                NaN
# 2952                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 2154                                                NaN
# 2420                                                NaN
# 2686                                                NaN
# 2952                                                NaN

# %%
#isin( [,] ) 
#~ negação

table1[~table1['Time'].isin(['1990'])]
# Out:
#                                                   Time    Country Name  \
# 266                                               2000     Afghanistan
# 267                                               2000         Albania
# 268                                               2000         Algeria
# 269                                               2000  American Samoa
# 270                                               2000         Andorra
# ...                                                ...             ...
# 3192                                               NaN             NaN
# 3193                                               NaN             NaN
# 3194                                               NaN             NaN
# 3195  Data from database: World Development Indicators             NaN
# 3196                          Last Updated: 10/26/2023             NaN
#
#       Firms with female top manager (% of firms)  \
# 266                                          NaN
# 267                                          NaN
# 268                                          NaN
# 269                                          NaN
# 270                                          NaN
# ...                                          ...
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 266                                      16.542629
# 267                                      42.026200
# 268                                      13.828949
# 269                                            NaN
# 270                                            NaN
# ...                                            ...
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 266                                      7.534
# 267                                      2.231
# 268                                      2.566
# 269                                        NaN
# 270                                        NaN
# ...                                        ...
# 3192                                       NaN
# 3193                                       NaN
# 3194                                       NaN
# 3195                                       NaN
# 3196                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 266                                                 NaN
# 267                                             3.43017
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 266                                                 NaN
# 267                                                 NaN
# 268                                                 NaN
# 269                                                 NaN
# 270                                                 NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
# [2931 rows x 15 columns]

# %% [markdown]
# ## [**6.5 Selecionar uma lista de valores para uma coluna | .isin()**](#Índice)  <a class="anchor"  id="III65"></a>

# %%
#isin( [,] ) 

table1.loc[(table1['Country Name'].isin(['Brazil','Argentina'])) & ((table1['Time'] >= '2019'))].drop_duplicates()
# Out:
#       Time Country Name  Firms with female top manager (% of firms)  \
# 2135  2019    Argentina                                         NaN
# 2154  2019       Brazil                                         NaN
# 2401  2020    Argentina                                         NaN
# 2420  2020       Brazil                                         NaN
# 2667  2021    Argentina                                         NaN
# 2686  2021       Brazil                                         NaN
# 2933  2022    Argentina                                         NaN
# 2952  2022       Brazil                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 2135                                     42.376056
# 2154                                     43.736217
# 2401                                     42.393834
# 2420                                     42.605281
# 2667                                     42.533911
# 2686                                     43.117615
# 2933                                     43.081417
# 2952                                     43.579161
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 2135                                     1.994
# 2154                                     1.703
# 2401                                     1.911
# 2420                                     1.649
# 2667                                     1.885
# 2686                                     1.641
# 2933                                       NaN
# 2952                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                          94.919998
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                          94.690002
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                          94.449997
#
#       Government expenditure on education, total (% of GDP)  \
# 2135                                            4.77760
# 2154                                            5.96347
# 2401                                            5.27964
# 2420                                            5.77150
# 2667                                            4.64760
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                          12.541869
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                NaN
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 2135                                                NaN
# 2154                                                NaN
# 2401                                                2.4
# 2420                                                NaN
# 2667                                                NaN
# 2686                                                NaN
# 2933                                                NaN
# 2952                                                NaN

# %% [markdown]
# ## [**6.6 .startswith(), endswith(), contains()**](#Índice)  <a class="anchor"  id="III66"></a>

# %%
table1[table1['Country Name'].str.startswith('B',na=False)]
# Out:
#       Time            Country Name  \
# 13    1990            Bahamas, The
# 14    1990                 Bahrain
# 15    1990              Bangladesh
# 16    1990                Barbados
# 17    1990                 Belarus
# ...    ...                     ...
# 2953  2022  British Virgin Islands
# 2954  2022       Brunei Darussalam
# 2955  2022                Bulgaria
# 2956  2022            Burkina Faso
# 2957  2022                 Burundi
#
#       Firms with female top manager (% of firms)  \
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# ...                                          ...
# 2953                                         NaN
# 2954                                         NaN
# 2955                                         NaN
# 2956                                         NaN
# 2957                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 13                                       46.305965
# 14                                       16.710151
# 15                                       21.748204
# 16                                       46.928093
# 17                                       48.802979
# ...                                            ...
# 2953                                           NaN
# 2954                                     41.819671
# 2955                                     46.438465
# 2956                                     45.254039
# 2957                                     51.959118
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 13                                       2.527
# 14                                       3.758
# 15                                       4.479
# 16                                       1.740
# 17                                       1.913
# ...                                        ...
# 2953                                       NaN
# 2954                                       NaN
# 2955                                       NaN
# 2956                                       NaN
# 2957                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                          29.120001
# 2957                                          69.440002
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                          34.490002
# 2957                                          75.540001
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                          40.070000
# 2957                                          81.839996
#
#       Government expenditure on education, total (% of GDP)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                             1.519120
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                           5.276512
# 2957                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# ...                                                 ...
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
#
# [228 rows x 15 columns]

# %%
table1[table1['Country Name'].str.endswith('ania',na=False)].drop_duplicates().head()
# Out:
#      Time Country Name  Firms with female top manager (% of firms)  \
# 1    1990      Albania                                         NaN
# 115  1990    Lithuania                                         NaN
# 125  1990   Mauritania                                         NaN
# 160  1990      Romania                                         NaN
# 191  1990     Tanzania                                         NaN
#
#      Labor force, female (% of total labor force)  \
# 1                                       40.805673
# 115                                     48.436506
# 125                                     27.379970
# 160                                     46.578520
# 191                                     49.826007
#
#      Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Fertility rate, total (births per woman)  \
# 1                                       2.900
# 115                                     2.030
# 125                                     6.056
# 160                                     1.830
# 191                                     6.195
#
#      Literacy rate, adult female (% of females ages 15 and above)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Literacy rate, adult total (% of people ages 15 and above)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Literacy rate, adult male (% of males ages 15 and above)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Government expenditure on education, total (% of GDP)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                            2.13807
#
#      Unmet need for contraception (% of married women ages 15-49)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN
#
#      Women who were first married by age 15 (% of women ages 20-24)
# 1                                                  NaN
# 115                                                NaN
# 125                                                NaN
# 160                                                NaN
# 191                                                NaN

# %%
table1[table1['Country Name'].str.contains('por',na=False)].drop_duplicates().head()
# Out:
#       Time Country Name  Firms with female top manager (% of firms)  \
# 171   1990    Singapore                                         NaN
# 437   2000    Singapore                                         NaN
# 703   2013    Singapore                                         NaN
# 969   2014    Singapore                                         NaN
# 1235  2015    Singapore                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 171                                      36.906174
# 437                                      38.779093
# 703                                      41.033493
# 969                                      41.355645
# 1235                                     41.678204
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 171                                       1.83
# 437                                       1.60
# 703                                       1.19
# 969                                       1.25
# 1235                                      1.24
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 171                                           83.026848
# 437                                           88.645180
# 703                                           94.641869
# 969                                           94.911324
# 1235                                          95.190651
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 171                                           89.096001
# 437                                           92.549400
# 703                                           96.548019
# 969                                           96.716690
# 1235                                          96.825493
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 171                                           95.093163
# 437                                           96.565102
# 703                                           98.542542
# 969                                           98.609016
# 1235                                          98.559570
#
#       Government expenditure on education, total (% of GDP)  \
# 171                                                 NaN
# 437                                            3.321300
# 703                                            2.854350
# 969                                            2.924367
# 1235                                           2.863093
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 171                                                 NaN
# 437                                                 NaN
# 703                                                 NaN
# 969                                                 NaN
# 1235                                                NaN

# %% [markdown]
# ## [**6.7 query**](#Índice)  <a class="anchor"  id="III67"></a>
#
# tbc

# %% [markdown]
# # [**7. .at e .iat**](#Índice) <a class="anchor"  id="III7"></a>
#
# tbc

# %% [markdown]
# #### [Voltar ao Índice](#Índice)
