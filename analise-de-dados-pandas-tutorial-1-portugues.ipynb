# %% [markdown]
# ## Sumário
#
# O objectivo deste tutorial (ou manual, em português arcaico;) ) é apresentar as funcionalidades da biblioteca Pandas para análise de dados.
# O tutorial está organizado em 5 capítulos:
#
# I - Importação de csv e excel
#
# II - Análise exploratória de dados
#
# III - Index, Slice, Select
#
# IV - Limpeza e transformação de dados
#
# V - Visualização de dados
#
# Este notebook debruça-se sobre os capítulos I e II.
#
# Cada capítulo segue a seguinte estrutura: introdução, tabela sumário, secções e subsecções.

# %% [markdown]
# ## Índice <a class="anchor"  id="Índice"></a>
# * [**I. Importação de csv e excel**](#I)
# * [Introdução](#Ii)
# * [Tabela sumário](#It)
# * [1. CSV](#I1)
# * [2. Excel](#I2)
# * [**II. Análise exploratória de dados**](#II)
# * [Introdução](#IIi)
# * [Tabela sumário](#IIt)
# * [1. Primeiro contacto com os dados](#II1)
#     * [1.1 Dimensão da tabela e pré-visualização dos dados](#II11)
#     * [1.2 Colunas: nome e tipo de dados](#II12)
# * [2. Conhecer melhor as colunas](#II2)
#     * [2.1 Valores distintos: quantos, quais e frequência](#II21)
#     * [2.2 Identificar colunas com NA](#II22)
#     * [2.3 Excluir NA](#II23)
# * [3. Calcular estatísticas de cada coluna](#II3)
#     * [3.1 describe()](#II32)
#     * [3.2 Estatística descritiva](#II32)

# %% [markdown]
# # [**I. Importação de csv e excel**](#Índice)  <a class="anchor"  id="c1"></a>

# %% [markdown]
# # [**Introdução**](#Índice)  <a class="anchor"  id="Ii"></a>
#
# Neste capítulo vamos importar dados de ficheiros/arquivos de texto em formato csv e de folhas de cálculo em formato excel.
# Para adicionar um dataset ao notebook basta seleccionar "Add Data" no separador lateral. Neste tutorial usamos um csv extraído do Banco Mundial com diversos indicadores.

# %% [markdown]
# # [**Tabela sumário**](#Índice) <a class="anchor"  id="It"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# Importar csv|.read_csv()            | tabela = pd.read_csv('localização do arquivo/ficheiro')  |
# Importar excel|.read_excel()           | tabela = pd.read_csv('localização do arquivo/ficheiro') |
# Visualizar número total de linhas e de colunas |.shape   |table.shape|
# Visualizar primeiras linhas    |.head()             | tabela.head() |
# Visualizar últimas linhas |.tail()     |table.tail()|

# %% [markdown]
# # [**1. Importação de CSV**](#Índice)  <a class="anchor"  id="I1"></a>

# %%
#Importar pandas
import pandas as pd

file = '/kaggle/input/gender-statistics-1990-2021/88c52f5e-f72c-406d-a2e2-31309c9953de_Data.csv'

table1 = pd.read_csv(file)

# Averiguar número de linhas e de colunas (linhas, colunas)
table1.shape
# Out:
# (3197, 15)

# %%
table1.head(3)
# Out:
#    Time Country Name  Firms with female top manager (% of firms)  \
# 0  1990  Afghanistan                                         NaN
# 1  1990      Albania                                         NaN
# 2  1990      Algeria                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN

# %%
table1.tail()
# Out:
#                                                   Time Country Name  \
# 3192                                               NaN          NaN
# 3193                                               NaN          NaN
# 3194                                               NaN          NaN
# 3195  Data from database: World Development Indicators          NaN
# 3196                          Last Updated: 10/26/2023          NaN
#
#       Firms with female top manager (% of firms)  \
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 3192                                       NaN
# 3193                                       NaN
# 3194                                       NaN
# 3195                                       NaN
# 3196                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN

# %% [markdown]
# # [**2. Importação de excel**](#Índice) <a class="anchor"  id="I2"></a>

# %%
file2 = '/kaggle/input/gender-statistics-1990-2021/P_Data_Extract_From_World_Development_Indicators.xlsx'

table2 = pd.read_excel(file2)

table2.shape
# Out:
# (271, 65)

# %%
table1.head()
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
table2.tail()
# Out:
#                                           Series Name Country Name 1960 1961  \
# 266                                               NaN          NaN  NaN  NaN
# 267                                               NaN          NaN  NaN  NaN
# 268                                               NaN          NaN  NaN  NaN
# 269  Data from database: World Development Indicators          NaN  NaN  NaN
# 270                          Last Updated: 10/26/2023          NaN  NaN  NaN
#
#     1962 1963 1964 1965 1966 1967  ... 2013 2014 2015 2016 2017 2018 2019  \
# 266  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 267  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 268  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 269  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 270  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     2020 2021 2022
# 266  NaN  NaN  NaN
# 267  NaN  NaN  NaN
# 268  NaN  NaN  NaN
# 269  NaN  NaN  NaN
# 270  NaN  NaN  NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# # [**II. Análise exploratória de dados**](#Índice)  <a class="anchor"  id="II"></a>

# %% [markdown]
# # [**Introdução**](#Índice)  <a class="anchor"  id="IIi"></a>
#
# Neste capítulo vamos percorrer algumas das funcionalidades usadas na exploração de dados. No fundo, falamos de ferramentas que nos permitem conhecer os dados que temos em mãos.

# %% [markdown]
# # [**Tabela sumário**](#Índice) <a class="anchor"  id="IIt"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# Número total de linhas e de colunas |.shape   |table.shape|
# Sumário da tabela              |.info()             |table.info()|
# Visualizar primeiras linhas    |.head()             |table.head() |
# Visualizar últimas linhas      |.tail()             |table.tail()|
# Lista com nome das colunas     |.columns            |table.columns
# Averiguar o tipo de dados de cada coluna |.dtypes   |table.dtypes
# Número de valores distintos numa coluna|.nunique()  |table['column'].nunique()
# Lista de valores distintos numa coluna|.unique()    |table['column'].unique()
# Frequência de cada valor distinto numa coluna|.value_counts()| table[column].value_counts()
# Estatísticas várias            |.describe()         |table.describe()|
# Média                          |.mean()             |column.mean()
# Mediana                        |.median()           |column.median()
# Desvio padrão                  |.std()              |column.std()
# Coeficiente de correlação de Pearson|.corr()        |column1.corr(column2,  method='pearson', min_periods=None)
# Covariância                    |.cov()              |column1.cov(column2, min_periods=None)
# Moda| .mode()|df.mode()
# |.isna()/.isnull()|
# |.notna()/notnull()|

# %% [markdown]
# # [**1. Primeiro contacto com os dados**](#Índice)  <a class="anchor"  id="II1"></a>

# %% [markdown]
# ## [**1.1 Dimensão da tabela e pré-visualização dos dados**](#Índice)  <a class="anchor"  id="II11"></a>

# %%
#O tamanho conta! Vamos ver quantas linhas e quantas colunas tem a nossa tabela.
#(linhas, colunas)

table1.shape
# Out:
# (3197, 15)

# %%
#Espreitar as primeiras linhas da tabela

table1.head()
# Out:
#    Time    Country Name  Firms with female top manager (% of firms)  \
# 0  1990     Afghanistan                                         NaN
# 1  1990         Albania                                         NaN
# 2  1990         Algeria                                         NaN
# 3  1990  American Samoa                                         NaN
# 4  1990         Andorra                                         NaN
#
#    Labor force, female (% of total labor force)  \
# 0                                     16.866045
# 1                                     40.805673
# 2                                     12.238081
# 3                                           NaN
# 4                                           NaN
#
#    Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fertility rate, total (births per woman)  \
# 0                                     7.565
# 1                                     2.900
# 2                                     4.556
# 3                                       NaN
# 4                                       NaN
#
#    Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure on education, total (% of GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 15 (% of women ages 20-24)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Ou as últimas...

table1.tail()
# Out:
#                                                   Time Country Name  \
# 3192                                               NaN          NaN
# 3193                                               NaN          NaN
# 3194                                               NaN          NaN
# 3195  Data from database: World Development Indicators          NaN
# 3196                          Last Updated: 10/26/2023          NaN
#
#       Firms with female top manager (% of firms)  \
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 3192                                       NaN
# 3193                                       NaN
# 3194                                       NaN
# 3195                                       NaN
# 3196                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN

# %% [markdown]
# ## [**1.2 Colunas: nome e tipo de dados**](#Índice)  <a class="anchor"  id="II12"></a>

# %%
#Obter uma lista com os nomes das colunas

table1.columns
# Out:
# Index(['Time', 'Country Name', 'Firms with female top manager (% of firms)',
#        'Labor force, female (% of total labor force)',
#        'Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)',
#        'Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)',
#        'Fertility rate, total (births per woman)',
#        'Literacy rate, adult female (% of females ages 15 and above)',
#        'Literacy rate, adult total (% of people ages 15 and above)',
#        'Literacy rate, adult male (% of males ages 15 and above)',
#        'Government expenditure on education, total (% of GDP)',
#        'Unmet need for contraception (% of married women ages 15-49)',
#        'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)',
#        'Women who believe a husband is justified in beating his wife when she goes out without telling him (%)',
#        'Women who were first married by age 15 (% of women ages 20-24)'],
#       dtype='object')

# %%
table1.columns.to_list()
# Out:
# ['Time',
#  'Country Name',
#  'Firms with female top manager (% of firms)',
#  'Labor force, female (% of total labor force)',
#  'Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)',
#  'Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)',
#  'Fertility rate, total (births per woman)',
#  'Literacy rate, adult female (% of females ages 15 and above)',
#  'Literacy rate, adult total (% of people ages 15 and above)',
#  'Literacy rate, adult male (% of males ages 15 and above)',
#  'Government expenditure on education, total (% of GDP)',
#  'Unmet need for contraception (% of married women ages 15-49)',
#  'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)',
#  'Women who believe a husband is justified in beating his wife when she goes out without telling him (%)',
#  'Women who were first married by age 15 (% of women ages 20-24)']

# %%
"""
Averiguar o tipo de dados presente em cada coluna.
Pode ser útil para identificar necessidades de transformação.
Por exemplo, converter texto (string) num formato numérico.
Ou uma coluna com datas mas cujo tipo de dados é importado como texto,
podendo ser necessário converter em date/datetime.
"""

table1.dtypes
# Out:
# Time                                                                                                                                            object
# Country Name                                                                                                                                    object
# Firms with female top manager (% of firms)                                                                                                     float64
# Labor force, female (% of total labor force)                                                                                                   float64
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                           float64
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                             float64
# Fertility rate, total (births per woman)                                                                                                       float64
# Literacy rate, adult female (% of females ages 15 and above)                                                                                   float64
# Literacy rate, adult total (% of people ages 15 and above)                                                                                     float64
# Literacy rate, adult male (% of males ages 15 and above)                                                                                       float64
# Government expenditure on education, total (% of GDP)                                                                                          float64
# Unmet need for contraception (% of married women ages 15-49)                                                                                   float64
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)    float64
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                         float64
# Women who were first married by age 15 (% of women ages 20-24)                                                                                 float64
# dtype: object

# %% [markdown]
# # [**2. Conhecer melhor uma coluna específica**](#Índice)  <a class="anchor"  id="II2"></a>

# %% [markdown]
# ## [**2.1 Valores distintos: quantos, quais e frequência**](#Índice)  <a class="anchor"  id="II21"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# Número de valores distintos numa coluna|.nunique()  |table['column'].nunique()
# Lista de valores distintos numa coluna|.unique()    |table['column'].unique()
# Frequência de cada valor distinto numa coluna|.value_counts()|

# %%
"""Averiguar quantos valores distintos existem numa coluna específica, 
neste caso, 'Time'.
"""

table1['Time'].nunique()
# Out:
# 14

# %% [markdown]
# Neste caso, ficamos a saber que apesar de o período ir de 1990 até 2021, apenas 14 anos constam dos dados. Quais serão os anos em falta?

# %%
#Lista com a identificação dos valores distintos da coluna 'Time'

table1['Time'].unique()
# Out:
# array(['1990', '2000', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', nan,
#        'Data from database: World Development Indicators',
#        'Last Updated: 10/26/2023'], dtype=object)

# %% [markdown]
# Percebemos agora que a periodicidade de reporte dos dados só passou a ser anual no ano de 2013.

# %%
#Frequência de cada valor distinto.
#Neste caso, verificamos que há 266 linhas para cada ano diferente.
#Por defeito, value_counts(dropNA=True)

table1['Time'].value_counts()
# Out:
# Time
# 1990                                                266
# 2000                                                266
# 2013                                                266
# 2014                                                266
# 2015                                                266
# 2016                                                266
# 2017                                                266
# 2018                                                266
# 2019                                                266
# 2020                                                266
# 2021                                                266
# 2022                                                266
# Data from database: World Development Indicators      1
# Last Updated: 10/26/2023                              1
# Name: count, dtype: int64

# %%
"""
Frequência de cada valor distinto.
Neste caso, não se exclui os NA e são apresentados na listagem: NaN = 3
Estes NA dizem respeito a linhas na coluna 'Time'.
Há muitos outros NA nas restantes colunas.
"""

table1['Time'].value_counts(dropna=False)
# Out:
# Time
# 1990                                                266
# 2000                                                266
# 2013                                                266
# 2014                                                266
# 2015                                                266
# 2016                                                266
# 2017                                                266
# 2018                                                266
# 2019                                                266
# 2020                                                266
# 2021                                                266
# 2022                                                266
# NaN                                                   3
# Data from database: World Development Indicators      1
# Last Updated: 10/26/2023                              1
# Name: count, dtype: int64

# %% [markdown]
# ## [**2.2 Identificar colunas com NA**](#Índice)  <a class="anchor"  id="II22"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|Pergunta | Resposta
# :----|:---------------------------------|:---------------------------------|:-----|:-----
# Identificar célula como sendo NA|.isna()/.isnull()|table.isna()|A célula é NA?|True - É NA|
# Identificar presença de  NA numa coluna |.isna().all/.isnull().all| table.isna().all()|Existem algum NA?| True - Existe pelo menos um NA na coluna
# Apurar total de NA por coluna | .isna().sum()/.isnull().sum() | table.isna().sum()| Quantos NA na coluna?
# Apurar total de NA na tabela | .isna().sum().sum()/""|table.isna().sum().sum()| Quantos NA na tabela?
#  | | |||
#   | | |||
# Identificar célula como não sendo NA|.notna()/.notnull()|table.notna()|A célula é não NA?|True - Não é NA|
# Identificar não existência de NA numa coluna | .notna()/notnull()| table.notna()|Não existem NA?|True - Não existe nenhum NA na coluna
# Calcular total de não NA por coluna |.notna().sum()/notnull().sum() | table.notna()sum()|Quantos não NA?|

# %% [markdown]
# ### isna()

# %%
"""Produz um tabela de dimensão igual à tabela em análise, em que cada
célula é preenchida com:
    True = caso o valor na tabela em análise seja NA;
    False = caso não seja.
"""

table1.isna()
# Out:
#        Time  Country Name  Firms with female top manager (% of firms)  \
# 0     False         False                                        True
# 1     False         False                                        True
# 2     False         False                                        True
# 3     False         False                                        True
# 4     False         False                                        True
# ...     ...           ...                                         ...
# 3192   True          True                                        True
# 3193   True          True                                        True
# 3194   True          True                                        True
# 3195  False          True                                        True
# 3196  False          True                                        True
#
#       Labor force, female (% of total labor force)  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                             True
# 4                                             True
# ...                                            ...
# 3192                                          True
# 3193                                          True
# 3194                                          True
# 3195                                          True
# 3196                                          True
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Fertility rate, total (births per woman)  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                         True
# 4                                         True
# ...                                        ...
# 3192                                      True
# 3193                                      True
# 3194                                      True
# 3195                                      True
# 3196                                      True
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 3192                                               True
# 3193                                               True
# 3194                                               True
# 3195                                               True
# 3196                                               True
#
# [3197 rows x 15 columns]

# %% [markdown]
# ### isna().all()

# %%
"""
Acrescentando .all" ficamos com uma visão agregada.
False - nem todos os valores da coluna são NA;
True - todas as linhas dessa coluna são NA.
"""

table1.isna().all()
# Out:
# Time                                                                                                                                           False
# Country Name                                                                                                                                   False
# Firms with female top manager (% of firms)                                                                                                     False
# Labor force, female (% of total labor force)                                                                                                   False
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                           False
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                             False
# Fertility rate, total (births per woman)                                                                                                       False
# Literacy rate, adult female (% of females ages 15 and above)                                                                                   False
# Literacy rate, adult total (% of people ages 15 and above)                                                                                     False
# Literacy rate, adult male (% of males ages 15 and above)                                                                                       False
# Government expenditure on education, total (% of GDP)                                                                                          False
# Unmet need for contraception (% of married women ages 15-49)                                                                                   False
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)    False
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                         False
# Women who were first married by age 15 (% of women ages 20-24)                                                                                 False
# dtype: bool

# %% [markdown]
# ### isna().sum()

# %%
#Identifica o total de NA para cada coluna

table1.isna().sum()
# Out:
# Time                                                                                                                                              3
# Country Name                                                                                                                                      5
# Firms with female top manager (% of firms)                                                                                                     2983
# Labor force, female (% of total labor force)                                                                                                    385
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                           3125
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                             3125
# Fertility rate, total (births per woman)                                                                                                        357
# Literacy rate, adult female (% of females ages 15 and above)                                                                                   2298
# Literacy rate, adult total (% of people ages 15 and above)                                                                                     2297
# Literacy rate, adult male (% of males ages 15 and above)                                                                                       2299
# Government expenditure on education, total (% of GDP)                                                                                          1257
# Unmet need for contraception (% of married women ages 15-49)                                                                                   2898
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)    3140
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                         3122
# Women who were first married by age 15 (% of women ages 20-24)                                                                                 3039
# dtype: int64

# %% [markdown]
# ### isna().sum().sum()

# %%
table1.isna().sum().sum()
# Out:
# 30333

# %% [markdown]
# ### notna()

# %%
"""Produz um tabela de dimensão igual à tabela em análise, em que cada
célula é preenchida com:
    True = caso o valor na tabela em análise seja NA;
    False = caso não seja.
"""


table1.notna()
# Out:
#        Time  Country Name  Firms with female top manager (% of firms)  \
# 0      True          True                                       False
# 1      True          True                                       False
# 2      True          True                                       False
# 3      True          True                                       False
# 4      True          True                                       False
# ...     ...           ...                                         ...
# 3192  False         False                                       False
# 3193  False         False                                       False
# 3194  False         False                                       False
# 3195   True         False                                       False
# 3196   True         False                                       False
#
#       Labor force, female (% of total labor force)  \
# 0                                             True
# 1                                             True
# 2                                             True
# 3                                            False
# 4                                            False
# ...                                            ...
# 3192                                         False
# 3193                                         False
# 3194                                         False
# 3195                                         False
# 3196                                         False
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Fertility rate, total (births per woman)  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                        False
# 4                                        False
# ...                                        ...
# 3192                                     False
# 3193                                     False
# 3194                                     False
# 3195                                     False
# 3196                                     False
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3192                                              False
# 3193                                              False
# 3194                                              False
# 3195                                              False
# 3196                                              False
#
# [3197 rows x 15 columns]

# %% [markdown]
# ### notna().all()

# %%
"""
Acrescentado "".all" ficamos com uma visão agregada.
False - existe pelo menos um NA;
True - não existe nenhum NA
"""

table1.notna().all()
# Out:
# Time                                                                                                                                           False
# Country Name                                                                                                                                   False
# Firms with female top manager (% of firms)                                                                                                     False
# Labor force, female (% of total labor force)                                                                                                   False
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                           False
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                             False
# Fertility rate, total (births per woman)                                                                                                       False
# Literacy rate, adult female (% of females ages 15 and above)                                                                                   False
# Literacy rate, adult total (% of people ages 15 and above)                                                                                     False
# Literacy rate, adult male (% of males ages 15 and above)                                                                                       False
# Government expenditure on education, total (% of GDP)                                                                                          False
# Unmet need for contraception (% of married women ages 15-49)                                                                                   False
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)    False
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                         False
# Women who were first married by age 15 (% of women ages 20-24)                                                                                 False
# dtype: bool

# %% [markdown]
# ### notna().sum()

# %%
"""
Total de valores não NA em cada coluna
"""

table1.notna().sum()
# Out:
# Time                                                                                                                                           3194
# Country Name                                                                                                                                   3192
# Firms with female top manager (% of firms)                                                                                                      214
# Labor force, female (% of total labor force)                                                                                                   2812
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)                                                             72
# Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)                                                               72
# Fertility rate, total (births per woman)                                                                                                       2840
# Literacy rate, adult female (% of females ages 15 and above)                                                                                    899
# Literacy rate, adult total (% of people ages 15 and above)                                                                                      900
# Literacy rate, adult male (% of males ages 15 and above)                                                                                        898
# Government expenditure on education, total (% of GDP)                                                                                          1940
# Unmet need for contraception (% of married women ages 15-49)                                                                                    299
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)      57
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%)                                           75
# Women who were first married by age 15 (% of women ages 20-24)                                                                                  158
# dtype: int64

# %%
#True - existe algum NA; False - não existe nenhum NA na coluna.

table1['Firms with female top manager (% of firms)'].isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3192    True
# 3193    True
# 3194    True
# 3195    True
# 3196    True
# Name: Firms with female top manager (% of firms), Length: 3197, dtype: bool

# %%
"""Com .all ficamos com uma visão agregada.
True - existe pelo menos um NA nesta coluna; False - não há nenhum NA nesta coluna.
"""

table1['Firms with female top manager (% of firms)'].isna().all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3192    True
# 3193    True
# 3194    True
# 3195    True
# 3196    True
# Name: Firms with female top manager (% of firms), Length: 3197, dtype: bool>

# %%
#Existem 2983 valores em falta nesta coluna.

table1['Firms with female top manager (% of firms)'].isna().sum()
# Out:
# 2983

# %% [markdown]
# ## [**2.3 Excluir NA**](#Índice)  <a class="anchor"  id="II23"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|Pergunta | Resposta
# :----|:---------------------------------|:---------------------------------|:-----|:-----
# Excluir linhas com valores NA|.isna()/.isnull()|table[table.isna()]

# %%
#????

table1[table1.notna()]
# Out:
#                                                   Time    Country Name  \
# 0                                                 1990     Afghanistan
# 1                                                 1990         Albania
# 2                                                 1990         Algeria
# 3                                                 1990  American Samoa
# 4                                                 1990         Andorra
# ...                                                ...             ...
# 3192                                               NaN             NaN
# 3193                                               NaN             NaN
# 3194                                               NaN             NaN
# 3195  Data from database: World Development Indicators             NaN
# 3196                          Last Updated: 10/26/2023             NaN
#
#       Firms with female top manager (% of firms)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3192                                         NaN
# 3193                                         NaN
# 3194                                         NaN
# 3195                                         NaN
# 3196                                         NaN
#
#       Labor force, female (% of total labor force)  \
# 0                                        16.866045
# 1                                        40.805673
# 2                                        12.238081
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3192                                           NaN
# 3193                                           NaN
# 3194                                           NaN
# 3195                                           NaN
# 3196                                           NaN
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 0                                        7.565
# 1                                        2.900
# 2                                        4.556
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 3192                                       NaN
# 3193                                       NaN
# 3194                                       NaN
# 3195                                       NaN
# 3196                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
#
# [3197 rows x 15 columns]

# %%
#Exlui todas as linhas em que exista um NA na coluna indicada.
#notna() filtra as linhas que não são NA.

table1[table1['Firms with female top manager (% of firms)'].notna()]
# Out:
#       Time  Country Name  Firms with female top manager (% of firms)  \
# 533   2013       Albania                                        12.2
# 540   2013       Armenia                                        14.1
# 544   2013    Azerbaijan                                         2.6
# 547   2013    Bangladesh                                         4.8
# 549   2013       Belarus                                        32.2
# ...    ...           ...                                         ...
# 3015  2022         India                                         6.8
# 3018  2022          Iraq                                         1.6
# 3044  2022    Madagascar                                        37.3
# 3075  2022      Pakistan                                         3.4
# 3092  2022  Saudi Arabia                                         3.0
#
#       Labor force, female (% of total labor force)  \
# 533                                      41.853022
# 540                                      50.483535
# 544                                      49.915723
# 547                                      28.559370
# 549                                      49.902654
# ...                                            ...
# 3015                                     23.542186
# 3018                                     14.402375
# 3044                                     48.970102
# 3075                                     23.311754
# 3092                                     18.872550
#
#       Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                                 NaN
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
#       Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                                 NaN
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
#       Fertility rate, total (births per woman)  \
# 533                                      1.697
# 540                                      1.600
# 544                                      1.980
# 547                                      2.184
# 549                                      1.668
# ...                                        ...
# 3015                                       NaN
# 3018                                       NaN
# 3044                                       NaN
# 3075                                       NaN
# 3092                                       NaN
#
#       Literacy rate, adult female (% of females ages 15 and above)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                           99.716820
# 547                                           57.789001
# 549                                                 NaN
# ...                                                 ...
# 3015                                          69.102150
# 3018                                                NaN
# 3044                                          76.029999
# 3075                                                NaN
# 3092                                                NaN
#
#       Literacy rate, adult total (% of people ages 15 and above)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                           99.789360
# 547                                           61.015541
# 549                                                 NaN
# ...                                                 ...
# 3015                                          76.322777
# 3018                                                NaN
# 3044                                          77.480003
# 3075                                                NaN
# 3092                                                NaN
#
#       Literacy rate, adult male (% of males ages 15 and above)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                           99.865921
# 547                                           64.213768
# 549                                                 NaN
# ...                                                 ...
# 3015                                          83.451813
# 3018                                                NaN
# 3044                                          78.930000
# 3075                                                NaN
# 3092                                                NaN
#
#       Government expenditure on education, total (% of GDP)  \
# 533                                            3.539300
# 540                                            2.650180
# 544                                            2.442130
# 547                                            1.966160
# 549                                            5.009420
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                           3.139020
# 3075                                           1.974449
# 3092                                                NaN
#
#       Unmet need for contraception (% of married women ages 15-49)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                           13.895225
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
#       Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                                 NaN
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                                 NaN
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)
# 533                                                 NaN
# 540                                                 NaN
# 544                                                 NaN
# 547                                                 NaN
# 549                                                 NaN
# ...                                                 ...
# 3015                                                NaN
# 3018                                                NaN
# 3044                                                NaN
# 3075                                                NaN
# 3092                                                NaN
#
# [214 rows x 15 columns]

# %% [markdown]
# # [**3. Conhecer as estatísticas de cada coluna**](#Índice)  <a class="anchor"  id="II3"></a>

# %% [markdown]
# ## [**3.1 describe()**](#Índice)  <a class="anchor"  id="II31"></a>

# %%
table1.describe()
# Out:
#        Firms with female top manager (% of firms)  \
# count                                  214.000000
# mean                                    17.735595
# std                                      9.799419
# min                                      0.900000
# 25%                                     11.675000
# 50%                                     17.236111
# 75%                                     22.075000
# max                                     64.800000
#
#        Labor force, female (% of total labor force)  \
# count                                   2812.000000
# mean                                      40.716067
# std                                        8.948439
# min                                        7.786072
# 25%                                       38.264280
# 50%                                       43.912770
# 75%                                       46.620032
# max                                       53.877323
#
#        Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)  \
# count                                          72.000000
# mean                                           17.473393
# std                                             4.220799
# min                                             5.020510
# 25%                                            15.289528
# 50%                                            16.819445
# 75%                                            19.604105
# max                                            29.521990
#
#        Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)  \
# count                                          72.000000
# mean                                            7.488555
# std                                             3.048831
# min                                             2.222220
# 25%                                             4.561298
# 50%                                             8.251190
# 75%                                             9.804170
# max                                            13.819440
#
#        Fertility rate, total (births per woman)  \
# count                               2840.000000
# mean                                   2.853734
# std                                    1.450443
# min                                    0.772000
# 25%                                    1.707823
# 50%                                    2.374071
# 75%                                    3.826809
# max                                    8.606000
#
#        Literacy rate, adult female (% of females ages 15 and above)  \
# count                                         899.000000
# mean                                           76.850282
# std                                            19.950783
# min                                            12.796420
# 25%                                            61.099674
# 50%                                            82.291847
# 75%                                            94.119415
# max                                           100.000000
#
#        Literacy rate, adult total (% of people ages 15 and above)  \
# count                                         900.000000
# mean                                           81.081614
# std                                            16.554112
# min                                            22.311550
# 25%                                            67.991722
# 50%                                            85.449062
# 75%                                            95.422932
# max                                           100.000000
#
#        Literacy rate, adult male (% of males ages 15 and above)  \
# count                                         898.000000
# mean                                           85.313455
# std                                            13.248059
# min                                            31.328791
# 25%                                            75.301466
# 50%                                            88.397068
# 75%                                            96.957411
# max                                           100.000000
#
#        Government expenditure on education, total (% of GDP)  \
# count                                        1940.000000
# mean                                            4.353550
# std                                             1.952922
# min                                             0.127174
# 25%                                             3.124990
# 50%                                             4.132104
# 75%                                             5.286955
# max                                            15.585125
#
#        Unmet need for contraception (% of married women ages 15-49)  \
# count                                         299.000000
# mean                                           19.678702
# std                                             8.707947
# min                                             3.492830
# 25%                                            12.653605
# 50%                                            19.700000
# 75%                                            25.559743
# max                                            40.200000
#
#        Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)  \
# count                                          57.000000
# mean                                           52.021053
# std                                            21.503386
# min                                             4.900000
# 25%                                            40.200000
# 50%                                            56.700000
# 75%                                            64.900000
# max                                            96.200000
#
#        Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# count                                          75.000000
# mean                                           27.065333
# std                                            16.942251
# min                                             0.800000
# 25%                                            14.450000
# 50%                                            25.500000
# 75%                                            38.950000
# max                                            66.900000
#
#        Women who were first married by age 15 (% of women ages 20-24)
# count                                         158.000000
# mean                                            6.259494
# std                                             6.599479
# min                                             0.000000
# 25%                                             1.425000
# 50%                                             4.600000
# 75%                                             8.775000
# max                                            38.200000

# %% [markdown]
# ## [**3.2 Estatística descritiva**](#Índice)  <a class="anchor"  id="II32"></a>

# %% [markdown]
# Objectivo|Funcionalidade           |Sintaxe|
# :----|:---------------------------------|:---------------------------------|
# Média                          |.mean()             |column.mean()
# Mediana                        |.median()           |column.median()
# Desvio padrão                  |.std()              |column.std()
# Coeficiente de correlação de Pearson|.corr()        |column1.corr(column2,  method='pearson', min_periods=None)
# Covariância                    |.cov()              |column1.cov(column2, min_periods=None)
# Moda| .mode()|column.mode()

# %%
#Média

table1['Firms with female top manager (% of firms)'].mean()
# Out:
# 17.735595133784226

# %%
#Mediana

table1['Firms with female top manager (% of firms)'].median()
# Out:
# 17.2361111111111

# %%
#Desvio padrão

table1['Firms with female top manager (% of firms)'].std()
# Out:
# 9.799418689843838

# %%
#Moda

table1['Firms with female top manager (% of firms)'].mode()
# Out:
# 0    14.0
# Name: Firms with female top manager (% of firms), dtype: float64

# %%
#Coeficiente de correlação entre duas variáveis(colunas)

table1['Firms with female top manager (% of firms)'].corr(table1['Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)'], method='pearson', min_periods=None)
# Out:
# -0.04073444659048812

# %%
#Covariância entre duas variáveis (colunas)

table1['Firms with female top manager (% of firms)'].cov(table1['Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)'], min_periods=None)
# Out:
# -2.39658245238095

# %% [markdown]
# #### [Voltar ao Índice](#Índice)
